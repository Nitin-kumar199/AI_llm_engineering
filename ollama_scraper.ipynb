# %%
import nest_asyncio
import asyncio
nest_asyncio.apply()

# %%
from ollama_scraper_playwright import EnhancedOpenAIScraper, analyze_content

# %%
result = asyncio.run(analyze_content())
print(result)
